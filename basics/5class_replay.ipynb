# %% [markdown]
# # Replay Strategy - 5 class grouped

# %%
#basic imports
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.preprocessing import MinMaxScaler as MMS
#torch
import torch
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
from torch.optim import Adam
from torch.optim import SGD
from torch.nn import CrossEntropyLoss
from torch.nn import MSELoss
from torch.nn import BCEWithLogitsLoss,BCELoss

#avalanche
from avalanche.models import SimpleMLP,MlpVAE,SlimResNet18,IcarlNet #model
from avalanche.training.supervised import Naive,Cumulative,Replay,LwF,ICaRL #cl strat
from avalanche.benchmarks.generators import nc_benchmark,ni_benchmark #custom benchmark
from avalanche.evaluation.metrics import forgetting_metrics, accuracy_metrics,loss_metrics, timing_metrics, cpu_usage_metrics, confusion_matrix_metrics, disk_usage_metrics #metrics
from avalanche.logging import InteractiveLogger, TextLogger, TensorboardLogger, CSVLogger #loggers
from avalanche.training.plugins import EvaluationPlugin
# Out:
# /Users/jesherjoshua/Library/Python/3.8/lib/python/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: dlopen(/Users/jesherjoshua/Library/Python/3.8/lib/python/site-packages/torchvision/image.so, 0x0006): Symbol not found: __ZN2at4_ops19empty_memory_format4callEN3c108ArrayRefIxEENS2_8optionalINS2_10ScalarTypeEEENS5_INS2_6LayoutEEENS5_INS2_6DeviceEEENS5_IbEENS5_INS2_12MemoryFormatEEE
#   Referenced from: /Users/jesherjoshua/Library/Python/3.8/lib/python/site-packages/torchvision/image.so
#   Expected in: /Users/jesherjoshua/Library/Python/3.8/lib/python/site-packages/torch/lib/libtorch_cpu.dylib
#   warn(f"Failed to load image Python extension: {e}")

# %%
df_train=pd.read_csv('./NIDS-datasets/fiveclass_train.csv')
df_train=df_train.drop(['Fwd Avg Bytes/Bulk','Fwd Avg Bulk Rate','Bwd Avg Bytes/Bulk','Bwd PSH Flags','Bwd URG Flags','Bwd Avg Bulk Rate','Fwd Avg Packets/Bulk','Bwd Avg Packets/Bulk'],axis=1)
df_test=pd.read_csv('./NIDS-datasets/fiveclass_test.csv')
df_test=df_test.drop(['Fwd Avg Bytes/Bulk','Fwd Avg Bulk Rate','Bwd Avg Bytes/Bulk','Bwd PSH Flags','Bwd URG Flags','Bwd Avg Bulk Rate','Fwd Avg Packets/Bulk','Bwd Avg Packets/Bulk'],axis=1)

# %%
df_train.head()
# Out:
#    Destination Port  Flow Duration  Total Fwd Packets  Total Backward Packets  \
# 0                80      6018089.0                  5                       3
# 1               443       323049.0                  8                       6
# 2                80     39270118.0                  9                      10
# 3              4848           43.0                  1                       1
# 4                80      5754816.0                  3                       1
#
#    Total Length of Fwd Packets  Total Length of Bwd Packets  \
# 0                          177                          994
# 1                          531                         3208
# 2                          898                         3944
# 3                            2                            6
# 4                           12                            0
#
#    Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# 0                    159                      0               35.400000
# 1                    194                      0               66.375000
# 2                    431                      0               99.777778
# 3                      2                      2                2.000000
# 4                      6                      0                4.000000
#
#    Fwd Packet Length Std  ...  Active Mean  Active Std  Active Max  \
# 0              69.143329  ...  275923.0000       0.000      275923
# 1              85.880211  ...       0.0000       0.000           0
# 2             187.795619  ...  123253.6667  149943.928      296394
# 3               0.000000  ...       0.0000       0.000           0
# 4               3.464102  ...       0.0000       0.000           0
#
#    Active Min   Idle Mean    Idle Std  Idle Max  Idle Min  Label  fiveLabels
# 0      275923   5742166.0    0.000000   5742166   5742166      0           0
# 1           0         0.0    0.000000         0         0      0           0
# 2       36667  10000000.0  300.561142  10000000   9999980      0           0
# 3           0         0.0    0.000000         0         0     10           3
# 4           0         0.0    0.000000         0         0      0           0
#
# [5 rows x 72 columns]

# %% [markdown]
# # Load Data

# %%
x_train=df_train.drop(['Label','fiveLabels'],axis=1)
y_train=df_train.fiveLabels
x_test=df_test.drop(['Label','fiveLabels'],axis=1)
y_test=df_test.fiveLabels
x_train.shape,x_test.shape,y_train.shape
x_train=x_train.values
x_test=x_test.values
y_train=y_train.values
y_test=y_test.values

# %% [markdown]
# # Create Benchmarks

# %%
mms=MMS(feature_range=(0,1))
x_train=mms.fit_transform(x_train)
x_test=mms.fit_transform(x_test)
x_train=torch.tensor(x_train,dtype=torch.float32)
y_train=torch.tensor(y_train)
x_test=torch.tensor(x_test,dtype=torch.float32)
y_test=torch.tensor(y_test)

# %%
type(x_train)
# Out:
# torch.Tensor

# %%
train_dataset=TensorDataset(x_train,y_train)
test_dataset=TensorDataset(x_test,y_test)
NC_benchmark = nc_benchmark(train_dataset=train_dataset,test_dataset = test_dataset,n_experiences=6,task_labels=False,shuffle=False)
#NI_benchmark=ni_benchmark(train_dataset=train_dataset,test_dataset = test_dataset,n_experiences=1,task_labels=False,seed=1234)

# %%
dir(NC_benchmark)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__orig_bases__',
#  '__parameters__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_check_and_adapt_user_stream_def',
#  '_check_stream_definitions',
#  '_check_stream_name',
#  '_classes_in_exp',
#  '_has_task_labels',
#  '_is_protocol',
#  '_make_original_dataset_fields',
#  '_make_stream_fields',
#  'class_ids_from_zero_from_first_exp',
#  'class_ids_from_zero_in_each_exp',
#  'class_mapping',
#  'classes_in_exp_range',
#  'classes_in_experience',
#  'classes_order',
#  'classes_order_original_ids',
#  'complete_test_set_only',
#  'experience_factory',
#  'get_classes_timeline',
#  'get_reproducibility_data',
#  'n_classes',
#  'n_classes_per_exp',
#  'n_experiences',
#  'original_classes_in_exp',
#  'original_test_dataset',
#  'original_train_dataset',
#  'stream_definitions',
#  'streams',
#  'task_labels',
#  'test_exps_patterns_assignment',
#  'test_stream',
#  'train_exps_patterns_assignment',
#  'train_stream']

# %%
x_train[0].dim(),y_train.dim()
# Out:
# (1, 1)

# %% [markdown]
# # Attempt SimpleMLP

# %%
model_2=SimpleMLP(num_classes=6,input_size=70)

# %%
text_logger = TextLogger(open('./logs/Replay_fiveclass.txt', 'a'))
interactive_logger = InteractiveLogger()
csv_logger=CSVLogger("./logs/Replay_fiveclass.csv")


eval_plugin = EvaluationPlugin(
    accuracy_metrics(minibatch=True, epoch=True, experience=True, stream=True),
    loss_metrics(minibatch=True, epoch=True, experience=True, stream=True),
    timing_metrics(epoch=True, epoch_running=True),
    forgetting_metrics(experience=True, stream=True),
    confusion_matrix_metrics(num_classes=NC_benchmark.n_classes, save_image=False,
                             stream=True),
    loggers=[interactive_logger, text_logger,csv_logger]
)
# Strategy
cl_strategy = Replay(
    model_2, Adam(model_2.parameters(), lr=0.001),
    CrossEntropyLoss(), train_mb_size=256, train_epochs=1, eval_mb_size=300,
    evaluator=eval_plugin)

# %%
y_train[0].size()
# Out:
# torch.Size([])

# %%
print('Starting experiment...')
results = []
for experience in NC_benchmark.train_stream:
    print("Start of experience: ", experience.current_experience)
    print("Current Classes: ", experience.classes_in_this_experience)

    # train returns a dictionary which contains all the metric values
    res = cl_strategy.train(experience)
    print('Training completed')

    print('Computing accuracy on the whole test set')
    # test also returns a dictionary which contains all the metric values
    results.append(cl_strategy.eval(NC_benchmark.test_stream))
# Out:
# Starting experiment...
# Start of experience:  0
# Current Classes:  [0]
# -- >> Start of training phase << --
# 100%|██████████| 7104/7104 [00:46<00:00, 153.10it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0024
# 	Loss_MB/train_phase/train_stream/Task000 = 0.0000
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Time_Epoch/train_phase/train_stream/Task000 = 46.4038
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9993
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 1516/1516 [00:10<00:00, 143.54it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 1.0000
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 169/169 [00:01<00:00, 151.52it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 43.8373
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 87/87 [00:00<00:00, 152.72it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 42.2096
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 106/106 [00:00<00:00, 150.91it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 25.9305
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 159.14it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 37.3628
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- Starting eval on experience 5 (Task 0) from test stream --
# 100%|██████████| 7/7 [00:00<00:00, 155.05it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 39.2398
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- >> End of eval phase << --
# 	ConfusionMatrix_Stream/eval_phase/test_stream =
# tensor([[454620,      0,      0,      0,      0,      0],
#         [ 50537,      0,      0,      0,      0,      0],
#         [ 25999,      0,      0,      0,      0,      0],
#         [ 31795,      0,      0,      0,      0,      0],
#         [  1309,      0,      0,      0,      0,      0],
#         [  1889,      0,      0,      0,      0,      0]])
# 	Loss_Stream/eval_phase/test_stream/Task000 = 7.5251
# 	StreamForgetting/eval_phase/test_stream = 0.0000
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.8030
# Start of experience:  1
# Current Classes:  [1]
# -- >> Start of training phase << --
# 100%|██████████| 7894/7894 [00:55<00:00, 141.68it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0417
# 	Loss_MB/train_phase/train_stream/Task000 = 0.0000
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Time_Epoch/train_phase/train_stream/Task000 = 55.7216
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9893
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 1516/1516 [00:11<00:00, 136.07it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.0040
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0097
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9960
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 169/169 [00:01<00:00, 137.79it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0547
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.9847
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 87/87 [00:00<00:00, 97.83it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 45.9029
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 106/106 [00:00<00:00, 142.26it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 137.4701
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 159.97it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 23.0024
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- Starting eval on experience 5 (Task 0) from test stream --
# 100%|██████████| 7/7 [00:00<00:00, 150.97it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 20.5529
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- >> End of eval phase << --
# 	ConfusionMatrix_Stream/eval_phase/test_stream =
# tensor([[452802,   1818,      0,      0,      0,      0],
#         [   771,  49766,      0,      0,      0,      0],
#         [ 13542,  12457,      0,      0,      0,      0],
#         [ 31755,     40,      0,      0,      0,      0],
#         [  1303,      6,      0,      0,      0,      0],
#         [  1887,      2,      0,      0,      0,      0]])
# 	Loss_Stream/eval_phase/test_stream/Task000 = 9.9628
# 	StreamForgetting/eval_phase/test_stream = 0.0040
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.8877
# Start of experience:  2
# Current Classes:  [2]
# -- >> Start of training phase << --
# 100%|██████████| 8300/8300 [01:02<00:00, 133.78it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0818
# 	Loss_MB/train_phase/train_stream/Task000 = 0.0064
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Time_Epoch/train_phase/train_stream/Task000 = 62.0427
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9907
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 1516/1516 [00:11<00:00, 131.60it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.0037
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0071
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9963
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 169/169 [00:01<00:00, 141.26it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp001 = -0.0015
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0484
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.9863
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 87/87 [00:00<00:00, 129.59it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 0.2645
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.9648
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 106/106 [00:00<00:00, 130.81it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 73.3396
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 157.51it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 26.0834
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- Starting eval on experience 5 (Task 0) from test stream --
# 100%|██████████| 7/7 [00:00<00:00, 132.05it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 28.5218
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- >> End of eval phase << --
# 	ConfusionMatrix_Stream/eval_phase/test_stream =
# tensor([[452930,   1581,    109,      0,      0,      0],
#         [   635,  49843,     59,      0,      0,      0],
#         [   908,      7,  25084,      0,      0,      0],
#         [ 31765,     30,      0,      0,      0,      0],
#         [  1302,      7,      0,      0,      0,      0],
#         [  1878,     11,      0,      0,      0,      0]])
# 	Loss_Stream/eval_phase/test_stream/Task000 = 4.2964
# 	StreamForgetting/eval_phase/test_stream = 0.0011
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.9324
# Start of experience:  3
# Current Classes:  [3]
# -- >> Start of training phase << --
# 100%|██████████| 8797/8797 [01:08<00:00, 127.96it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.1883
# 	Loss_MB/train_phase/train_stream/Task000 = 0.0104
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Time_Epoch/train_phase/train_stream/Task000 = 68.7503
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9738
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 1516/1516 [00:12<00:00, 122.01it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.0156
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0294
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9844
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 169/169 [00:01<00:00, 112.02it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp001 = -0.0036
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0368
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.9883
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 87/87 [00:00<00:00, 122.33it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp002 = -0.0037
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 0.1313
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.9685
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 106/106 [00:00<00:00, 117.74it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 0.2102
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.9943
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 139.21it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 22.2979
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- Starting eval on experience 5 (Task 0) from test stream --
# 100%|██████████| 7/7 [00:00<00:00, 147.09it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 26.0114
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- >> End of eval phase << --
# 	ConfusionMatrix_Stream/eval_phase/test_stream =
# tensor([[447525,    230,    117,   6748,      0,      0],
#         [   550,  49948,     39,      0,      0,      0],
#         [   720,      2,  25181,     96,      0,      0],
#         [   163,     17,      0,  31615,      0,      0],
#         [  1299,      9,      0,      1,      0,      0],
#         [  1393,    496,      0,      0,      0,      0]])
# 	Loss_Stream/eval_phase/test_stream/Task000 = 0.1831
# 	StreamForgetting/eval_phase/test_stream = 0.0028
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.9790
# Start of experience:  4
# Current Classes:  [4]
# -- >> Start of training phase << --
# 100%|██████████| 8817/8817 [01:16<00:00, 115.76it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0564
# 	Loss_MB/train_phase/train_stream/Task000 = 0.0497
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Time_Epoch/train_phase/train_stream/Task000 = 76.1723
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9813
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9859
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 1516/1516 [00:13<00:00, 111.81it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.0152
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0246
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9848
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 169/169 [00:01<00:00, 118.76it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp001 = -0.0068
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0317
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.9916
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 87/87 [00:00<00:00, 114.09it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp002 = -0.0021
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 0.1116
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.9669
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 106/106 [00:00<00:00, 119.63it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp003 = -0.0021
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 0.1977
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.9965
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 154.54it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 1.2238
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.4561
# -- Starting eval on experience 5 (Task 0) from test stream --
# 100%|██████████| 7/7 [00:00<00:00, 145.06it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 22.1029
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- >> End of eval phase << --
# 	ConfusionMatrix_Stream/eval_phase/test_stream =
# tensor([[447713,    217,     84,   6604,      2,      0],
#         [   425,  50112,      0,      0,      0,      0],
#         [   756,      8,  25139,     96,      0,      0],
#         [   103,      9,      0,  31683,      0,      0],
#         [   703,      9,      0,      0,    597,      0],
#         [  1381,    496,      0,      0,     12,      0]])
# 	Loss_Stream/eval_phase/test_stream/Task000 = 0.1154
# 	StreamForgetting/eval_phase/test_stream = 0.0010
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.9807
# Start of experience:  5
# Current Classes:  [5]
# -- >> Start of training phase << --
# 100%|██████████| 8847/8847 [01:14<00:00, 119.29it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0572
# 	Loss_MB/train_phase/train_stream/Task000 = 0.0004
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Time_Epoch/train_phase/train_stream/Task000 = 74.1578
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9808
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 1516/1516 [00:13<00:00, 111.50it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.0156
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0252
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9844
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 169/169 [00:01<00:00, 87.07it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp001 = -0.0097
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0215
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.9944
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 87/87 [00:00<00:00, 109.31it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp002 = -0.0054
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 0.1044
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.9702
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 106/106 [00:01<00:00, 98.50it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp003 = -0.0034
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 0.1752
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.9978
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 135.07it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp004 = -0.1268
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 0.8937
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.5829
# -- Starting eval on experience 5 (Task 0) from test stream --
# 100%|██████████| 7/7 [00:00<00:00, 140.08it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 0.6569
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.8385
# -- >> End of eval phase << --
# 	ConfusionMatrix_Stream/eval_phase/test_stream =
# tensor([[447531,    225,     51,   6597,     45,    171],
#         [   175,  50254,      0,      0,      2,    106],
#         [   675,      3,  25225,     96,      0,      0],
#         [    53,     17,      0,  31724,      1,      0],
#         [   538,      5,      0,      0,    763,      3],
#         [   299,      0,      0,      0,      6,   1584]])
# 	Loss_Stream/eval_phase/test_stream/Task000 = 0.0410
# 	StreamForgetting/eval_phase/test_stream = -0.0259
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.9840

# %%
torch.__version__
# Out:
# '1.13.1'
